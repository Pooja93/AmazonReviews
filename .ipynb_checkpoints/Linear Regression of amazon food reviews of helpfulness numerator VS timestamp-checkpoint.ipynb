# %%
import graphlab
# Out:
# A newer version of GraphLab Create (v1.10.1) is available! Your current version is v1.10.
#
# You can use pip to upgrade the graphlab-create package. For more information see https://dato.com/products/create/upgrade.

# %%
food_reviews = graphlab.SFrame('Downloads/amazon-fine-foods/Reviews.csv')
# Out:
# Unable to parse line "95303,B00401OZ1U,ATO7WKMVJD6XQ,"Curcio ""\""",0,0,5,1335398400,Metromint Water,Wonderful tasting water.  For one that doesn't like to drink soda's or juices because of the high sugar content this product is a great addition to the healthy drinking.  Also p..."
# 1 lines failed to parse correctly
# Finished parsing file /Users/pbhandary/Downloads/amazon-fine-foods/Reviews.csv
# Parsing completed. Parsed 100 lines in 0.545131 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,str,str,str,int,int,int,int,str,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# ...

# %%
food_reviews.head()
# Out:
# Columns:
# 	Id	int
# 	ProductId	str
# 	UserId	str
# 	ProfileName	str
# 	HelpfulnessNumerator	int
# 	HelpfulnessDenominator	int
# 	Score	int
# 	Time	int
# 	Summary	str
# 	Text	str
#
# Rows: 10
#
# Data:
# +----+------------+----------------+-------------------------------+----------------------+
# | Id | ProductId  |     UserId     |          ProfileName          | HelpfulnessNumerator |
# +----+------------+----------------+-------------------------------+----------------------+
# | 1  | B001E4KFG0 | A3SGXH7AUHU8GW |           delmartian          |          1           |
# | 2  | B00813GRG4 | A1D87F6ZCVE5NK |             dll pa            |          0           |
# | 3  | B000LQOCH0 | ABXLMWJIXXAIN  | Natalia Corres "Natalia Co... |          1           |
# | 4  | B000UA0QIQ | A395BORC6FGVXV |              Karl             |          3           |
# | 5  | B006K2ZZ7K | A1UQRSCLF8GW1T | Michael D. Bigham "M. Wassir" |          0           |
# ...

# %%
food_reviews.show('profile_name')
# Out:
# [WARNING] graphlab.data_structures.sframe: Column selection for SFrame.show is deprecated. To show only certain columns, use the sf[['column1', 'column2']] syntax or construct a new SFrame with the desired columns.
# Canvas is accessible via web browser at the URL: http://localhost:56534/index.html
# Opening Canvas in default web browser.

# %%
graphlab.canvas.set_target('ipynb')
food_reviews['ProfileName'].show()

# %%
food_reviews.show(view="Scatter Plot", x="Time", y="HelpfulnessNumerator")

# %%
food_reviews['HelpfulnessNumerator'].show()

# %%
food_review_frequent = food_reviews[food_reviews['ProfileName']=='C. F. Hill "CFH"']

# %%
food_review_frequent.show()

# %%
train_data,test_data = food_review_frequent.random_split(.8,seed=0)

# %%
helpfulness_predictor_model = graphlab.linear_regression.create(train_data, target='HelpfulnessNumerator', features=['ProfileName'],validation_set=None)
# Out:
# WARNING: Detected extremely low variance for feature(s) 'ProfileName' because all entries are nearly the same.
# Proceeding with model training using all features. If the model does not provide results of adequate quality, exclude the above mentioned feature(s) from the input dataset.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 358
# Number of features          : 1
# Number of unpacked features : 1
# Number of coefficients    : 1
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------+
# | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# +-----------+----------+--------------+--------------------+---------------+
# | 1         | 2        | 1.003307     | 45.966480          | 8.239027      |
# +-----------+----------+--------------+--------------------+---------------+
# ...

# %%
print sqft_model.evaluate(test_data)
# Out:
# {'max_error': 45.96648044692738, 'rmse': 7.467861112471173}

# %%
# Out:
# [ERROR] graphlab.toolkits._main: Toolkit error: Input data does not contain any rows.
# ---------------------------------------------------------------------------
# ToolkitError                              Traceback (most recent call last)
# <ipython-input-34-9b1a55ac688f> in <module>()
# ----> 1 print helpfulness_predictor_model.predict(food_review_frequent[food_review_frequent['Time']=='126843840019'])
#
# /Users/pbhandary/anaconda/envs/dato-env/lib/python2.7/site-packages/graphlab/toolkits/regression/linear_regression.pyc in predict(self, dataset, missing_value_action)
#     590
#     591         _mt._get_metric_tracker().track('toolkit.regression.linear_regression.predict')
# --> 592         return super(LinearRegression, self).predict(dataset, missing_value_action=missing_value_action)
#     593
#     594     @_collect_model_workflow
#
# ...

# %%
print food_review_frequent[food_review_frequent['Time']==12312864000]
# Out:
# +----+-----------+--------+-------------+----------------------+
# | Id | ProductId | UserId | ProfileName | HelpfulnessNumerator |
# +----+-----------+--------+-------------+----------------------+
# +----+-----------+--------+-------------+----------------------+
# +------------------------+-------+------+---------+
# | HelpfulnessDenominator | Score | Time | Summary |
# +------------------------+-------+------+---------+
# +------------------------+-------+------+---------+
# +------+
# | Text |
# +------+
# +------+
# [? rows x 10 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %%
food_review_frequent.show()

# %%
food_review_frequent.show(view="Scatter Plot", x="Time", y="HelpfulnessNumerator")

# %%
helpfulness_predictor_model.show()
